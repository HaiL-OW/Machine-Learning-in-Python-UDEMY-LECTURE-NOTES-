# %% [markdown]
# ## Lecture Notes on PCA and Manifold Learning from JosePortilla_UDEMY - Henric Jandoc

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use(['science', 'notebook', 'grid', 'no-latex'])

# %%
df = pd.read_csv('C:\\Users\\henri\\Documents\\Documents\\Python and Machine Learning\\UNZIP_FOR_NOTEBOOKS_FINAL\\DATA\\cancer_tumor_data_features.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X = scaler.fit_transform(df)

# %%
scaled_X
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
from sklearn.decomposition import PCA

# %%
# help(PCA)

# %%
pc_results = PCA(n_components=2)

# %%
pca_model.fit(scaled_X)  # calculating eigenstuffs, cov matrix
pca_model.transform(scaled_X)  # projecting / dot product
# Out:
# array([[ 9.19283683,  1.94858307],
#        [ 2.3878018 , -3.76817174],
#        [ 5.73389628, -1.0751738 ],
#        ...,
#        [ 1.25617928, -1.90229671],
#        [10.37479406,  1.67201011],
#        [-5.4752433 , -0.67063679]])

# %%
pc_results = pca_model.fit_transform(scaled_X)

# %%
from sklearn.datasets import load_breast_cancer
cancer_dictionary = load_breast_cancer()

# %%
plt.scatter(pc_results[:,0], pc_results[:,1], c = cancer_dictionary['target']) # error

# %%
pca_model.components_
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611302,
#          0.15189161,  0.06016536, -0.0347675 ,  0.19034877,  0.36657547,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443045,
#          0.2327159 ,  0.19720728,  0.13032156,  0.183848  ,  0.28009203,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796411, -0.00825724,  0.14188335,  0.27533947]])

# %%
df_comp = pd.DataFrame(pca_model.components_, index = ['PC1', 'PC2'], columns = df.columns)

# %%
df_comp
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# PC1     0.218902      0.103725        0.227537   0.220995         0.142590
# PC2    -0.233857     -0.059706       -0.215181  -0.231077         0.186113
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# PC1          0.239285        0.258400             0.260854       0.138167
# PC2          0.151892        0.060165            -0.034768       0.190349
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# PC1                0.064363  ...      0.227997       0.104469
# PC2                0.366575  ...     -0.219866      -0.045467
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# PC1         0.236640    0.224871          0.127953           0.210096
# PC2        -0.199878   -0.219352          0.172304           0.143593
#
#      worst concavity  worst concave points  worst symmetry  \
# ...

# %%
plt.figure(figsize = (20,3))
sns.heatmap(df_comp, annot = True)
# Out:
# <AxesSubplot:>

# %%
pca_30 = PCA(n_components = 30)
pca_30.fit(scaled_X)
pca_30.explained_variance_ratio_
# Out:
# array([4.42720256e-01, 1.89711820e-01, 9.39316326e-02, 6.60213492e-02,
#        5.49576849e-02, 4.02452204e-02, 2.25073371e-02, 1.58872380e-02,
#        1.38964937e-02, 1.16897819e-02, 9.79718988e-03, 8.70537901e-03,
#        8.04524987e-03, 5.23365745e-03, 3.13783217e-03, 2.66209337e-03,
#        1.97996793e-03, 1.75395945e-03, 1.64925306e-03, 1.03864675e-03,
#        9.99096464e-04, 9.14646751e-04, 8.11361259e-04, 6.01833567e-04,
#        5.16042379e-04, 2.72587995e-04, 2.30015463e-04, 5.29779290e-05,
#        2.49601032e-05, 4.43482743e-06])

# %%
explained_variance = []

for n in range(1,30):
    
    pca = PCA(n_components=n)
    pca.fit(scaled_X)
    
    explained_variance.append(np.sum(pca.explained_variance_ratio_))

# %%
plt.plot(range(1,30), explained_variance)
plt.xlabel('Num of Components')
plt.ylabel('Variance Explained')
# Out:
# Text(0, 0.5, 'Variance Explained')

# %%
pca_15 = PCA(n_components = 15)
pca_15.fit(scaled_X)
pca_model = PCA(n_components=15)
pca_results = pca_model.fit_transform(scaled_X)
np.sum(pca_15.explained_variance_ratio_)
# Out:
# 0.9864881227125468

# %%
plt.scatter(pca_results[:,0], pca_results[:,1], c = cancer_dictionary['target'])

# %% [markdown]
# ## Lecture Notes on Model Deployment
